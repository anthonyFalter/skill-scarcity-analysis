# %% [markdown]
# # Exploratory Data Analysis Phase
# - This phase explores the relationship between variables, what dtypes each variable has, distribution of data, detecting abnormalities and statistical evaluations.

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import
DATASET_FILEPATH = '../dataset/raw/'
DATASET_FILENAME = 'skill-scarcity-index.csv'

# Pandas import
df = pd.read_csv(DATASET_FILEPATH+DATASET_FILENAME, index_col=0)

# %%
# First 10 Rows
df.head(10)
# Out:
#               category       skill_name  demand_count  demand_pct  \
# snapshot_date
# 2026-07-12          ai      A/B Testing           115         4.7
# 2026-07-12          ai    Agile / Scrum            63         2.6
# 2026-07-12          ai        AI Agents           153         6.3
# 2026-07-12          ai  AI Coding Tools            32         1.3
# 2026-07-12          ai          Airflow            54         2.2
# 2026-07-12          ai              AWS           259        10.6
# 2026-07-12          ai            Azure           221         9.0
# 2026-07-12          ai         BigQuery            43         1.8
# 2026-07-12          ai               C#            42         1.7
# 2026-07-12          ai              C++            66         2.7
#
#                median_days_open  salary_premium_pct  repost_rate_pct  \
# snapshot_date
# 2026-07-12                  1.0                 3.9              2.0
# 2026-07-12                  1.0                42.5             14.0
# 2026-07-12                  NaN                45.5              5.9
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  9.0               -38.7             16.2
# 2026-07-12                  0.0               -29.2             11.2
# 2026-07-12                  0.0               -46.9             19.5
# 2026-07-12                  4.0                 NaN             22.2
# 2026-07-12                  0.0               -31.5              7.2
# 2026-07-12                  1.0               -10.9             18.0
#
#                scarcity_score
# snapshot_date
# 2026-07-12               49.2
# 2026-07-12               62.9
# 2026-07-12               72.0
# 2026-07-12                0.0
# 2026-07-12               57.2
# 2026-07-12               31.0
# 2026-07-12               28.3
# 2026-07-12               75.5
# 2026-07-12               25.0
# 2026-07-12               60.4

# %%
# Show category unique values
df['category'].unique()
# Out:
# <ArrowStringArray>
# ['ai', 'data', 'devops', 'engineering', 'product', 'security']
# Length: 6, dtype: str

# %%
# DTypes
df.dtypes
# Out:
# category                  str
# skill_name                str
# demand_count            int64
# demand_pct            float64
# median_days_open      float64
# salary_premium_pct    float64
# repost_rate_pct       float64
# scarcity_score        float64
# dtype: object

# %%
# Info
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4933 entries, 2026-07-12 to 2026-08-05
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   category            4933 non-null   str
#  1   skill_name          4933 non-null   str
#  2   demand_count        4933 non-null   int64
#  3   demand_pct          4933 non-null   float64
#  4   median_days_open    3898 non-null   float64
#  5   salary_premium_pct  3894 non-null   float64
#  6   repost_rate_pct     4933 non-null   float64
#  7   scarcity_score      4933 non-null   float64
# dtypes: float64(5), int64(1), str(2)
# memory usage: 464.7 KB

# %% [markdown]
# Inferences:
# - 1035 null values in ```median_days_open```, 1039 null values in ```salary_premium_pct```
# - Dtypes are right as they were.
# - valid? yes, but will do a deeper investigation for those null values before proceeding what to do with them.

# %%
# Describe numeric columns
df.describe()
# Out:
#        demand_count   demand_pct  median_days_open  salary_premium_pct  \
# count   4933.000000  4933.000000       3898.000000         3894.000000
# mean     189.864991     3.482506         11.601591            7.337365
# std      358.644820     6.127848         20.065420           46.851702
# min       10.000000     0.100000          0.000000          -71.100000
# 25%       23.000000     0.500000          0.000000          -28.400000
# 50%       55.000000     1.300000          1.000000           -3.800000
# 75%      178.000000     3.600000         15.000000           32.500000
# max     3422.000000    82.300000        108.000000          224.200000
#
#        repost_rate_pct  scarcity_score
# count      4933.000000     4933.000000
# mean          8.641597       40.934867
# std          10.852761       21.807479
# min           0.000000        0.000000
# 25%           0.000000       27.200000
# 50%           5.800000       40.200000
# 75%          13.200000       56.700000
# max         100.000000      100.000000

# %%
# Explore column with null values
median_days_open_null_sum = df['median_days_open'].isnull().sum()
salary_premium_pct_null_sum = df['salary_premium_pct'].isnull().sum()
print(f"Null Count (Median Days Open): {median_days_open_null_sum}")
print(f"Null Count (Salary Premium %): {salary_premium_pct_null_sum}")
# Out:
# Null Count (Median Days Open): 1035
# Null Count (Salary Premium %): 1039

# %% [markdown]
# ^ Values verified the inference of null values from .info()

# %%
# Show rows that have null values in the 'median_days_open' column
null_median_days = df[df['median_days_open'].isnull()]
print(f"Number of rows with Null Values: {len(null_median_days)}")
null_median_days
# Out:
# Number of rows with Null Values: 1035
#                category          skill_name  demand_count  demand_pct  \
# snapshot_date
# 2026-07-12           ai           AI Agents           153         6.3
# 2026-07-12           ai     AI Coding Tools            32         1.3
# 2026-07-12           ai   Incident Response            17         0.7
# 2026-07-12           ai  Prompt Engineering            45         1.8
# 2026-07-12           ai          Salesforce            17         0.7
# ...                 ...                 ...           ...         ...
# 2026-08-05     security       Elasticsearch            11         0.5
# 2026-08-05     security             GraphQL            10         0.4
# 2026-08-05     security                 MCP            10         0.4
# 2026-08-05     security              MLflow            14         0.6
# 2026-08-05     security          ServiceNow            17         0.7
#
#                median_days_open  salary_premium_pct  repost_rate_pct  \
# snapshot_date
# 2026-07-12                  NaN                45.5              5.9
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# ...                         ...                 ...              ...
# 2026-08-05                  NaN                 NaN              8.3
# 2026-08-05                  NaN                96.4              0.0
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                  NaN               -15.0              0.0
#
#                scarcity_score
# snapshot_date
# 2026-07-12               72.0
# 2026-07-12                0.0
# 2026-07-12                0.0
# 2026-07-12                0.0
# 2026-07-12                0.0
# ...                       ...
# 2026-08-05               83.7
# 2026-08-05               49.5
# 2026-08-05                0.0
# 2026-08-05                0.0
# 2026-08-05               17.7
#
# [1035 rows x 8 columns]

# %%
# Show rows that have null values in the 'salary_premium_pct' 
null_salary_premium_pct = df[df['salary_premium_pct'].isnull()]
print(f"Number of rows with Null Values: {len(null_salary_premium_pct)}")
null_salary_premium_pct
# Out:
# Number of rows with Null Values: 1039
#                category         skill_name  demand_count  demand_pct  \
# snapshot_date
# 2026-07-12           ai    AI Coding Tools            32         1.3
# 2026-07-12           ai           BigQuery            43         1.8
# 2026-07-12           ai            Datadog            31         1.3
# 2026-07-12           ai  Incident Response            17         0.7
# 2026-07-12           ai            MongoDB            51         2.1
# ...                 ...                ...           ...         ...
# 2026-08-05     security               Jira            13         0.5
# 2026-08-05     security                MCP            10         0.4
# 2026-08-05     security             MLflow            14         0.6
# 2026-08-05     security            Node.js            29         1.2
# 2026-08-05     security         TypeScript            57         2.4
#
#                median_days_open  salary_premium_pct  repost_rate_pct  \
# snapshot_date
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  4.0                 NaN             22.2
# 2026-07-12                 82.0                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  0.0                 NaN             16.4
# ...                         ...                 ...              ...
# 2026-08-05                 36.0                 NaN              0.0
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                 52.0                 NaN              0.0
# 2026-08-05                 28.0                 NaN              0.0
#
#                scarcity_score
# snapshot_date
# 2026-07-12                0.0
# 2026-07-12               75.5
# 2026-07-12               61.5
# 2026-07-12                0.0
# 2026-07-12               25.8
# ...                       ...
# 2026-08-05               37.3
# 2026-08-05                0.0
# 2026-08-05                0.0
# 2026-08-05               50.3
# 2026-08-05               35.4
#
# [1039 rows x 8 columns]

# %%
#  Rows where either 'median_days_open' or 'salary_premium_pct' is null
null_rows = df[df['median_days_open'].isnull() | df['salary_premium_pct'].isnull()]
print(f"Number of rows with Null Values: {len(null_rows)}")
null_rows
# Out:
# Number of rows with Null Values: 1617
#                category         skill_name  demand_count  demand_pct  \
# snapshot_date
# 2026-07-12           ai          AI Agents           153         6.3
# 2026-07-12           ai    AI Coding Tools            32         1.3
# 2026-07-12           ai           BigQuery            43         1.8
# 2026-07-12           ai            Datadog            31         1.3
# 2026-07-12           ai  Incident Response            17         0.7
# ...                 ...                ...           ...         ...
# 2026-08-05     security                MCP            10         0.4
# 2026-08-05     security             MLflow            14         0.6
# 2026-08-05     security            Node.js            29         1.2
# 2026-08-05     security         ServiceNow            17         0.7
# 2026-08-05     security         TypeScript            57         2.4
#
#                median_days_open  salary_premium_pct  repost_rate_pct  \
# snapshot_date
# 2026-07-12                  NaN                45.5              5.9
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  4.0                 NaN             22.2
# 2026-07-12                 82.0                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# ...                         ...                 ...              ...
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                 52.0                 NaN              0.0
# 2026-08-05                  NaN               -15.0              0.0
# 2026-08-05                 28.0                 NaN              0.0
#
#                scarcity_score
# snapshot_date
# 2026-07-12               72.0
# 2026-07-12                0.0
# 2026-07-12               75.5
# 2026-07-12               61.5
# 2026-07-12                0.0
# ...                       ...
# 2026-08-05                0.0
# 2026-08-05                0.0
# 2026-08-05               50.3
# 2026-08-05               17.7
# 2026-08-05               35.4
#
# [1617 rows x 8 columns]

# %%
# Rows where bothh 'median_days_open' and 'salary_premium_pct' are null
both_null_rows = df[df['median_days_open'].isnull() & df['salary_premium_pct'].isnull()]
print(f"Number of rows with Null Values: {len(both_null_rows)}")
both_null_rows
# Out:
# Number of rows with Null Values: 457
#                category          skill_name  demand_count  demand_pct  \
# snapshot_date
# 2026-07-12           ai     AI Coding Tools            32         1.3
# 2026-07-12           ai   Incident Response            17         0.7
# 2026-07-12           ai  Prompt Engineering            45         1.8
# 2026-07-12           ai          Salesforce            17         0.7
# 2026-07-12         data      Apache Iceberg            21         0.4
# ...                 ...                 ...           ...         ...
# 2026-08-05     security          Burp Suite            12         0.5
# 2026-08-05     security             Datadog            35         1.5
# 2026-08-05     security       Elasticsearch            11         0.5
# 2026-08-05     security                 MCP            10         0.4
# 2026-08-05     security              MLflow            14         0.6
#
#                median_days_open  salary_premium_pct  repost_rate_pct  \
# snapshot_date
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# 2026-07-12                  NaN                 NaN              0.0
# ...                         ...                 ...              ...
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                  NaN                 NaN              8.3
# 2026-08-05                  NaN                 NaN              0.0
# 2026-08-05                  NaN                 NaN              0.0
#
#                scarcity_score
# snapshot_date
# 2026-07-12                0.0
# 2026-07-12                0.0
# 2026-07-12                0.0
# 2026-07-12                0.0
# 2026-07-12                0.0
# ...                       ...
# 2026-08-05                0.0
# 2026-08-05                0.0
# 2026-08-05               83.7
# 2026-08-05                0.0
# 2026-08-05                0.0
#
# [457 rows x 8 columns]

# %% [markdown]
# The null results seem to be of missing metric data instead of actual abnormalities.
# - while some of the `median_days_open`,`salary_premium_pct`,`repost_rate_pct`,`scarcity_score` might be 0, this might be because the metrics simply cannot be computed for these rows.
# - Because we are also factoring in `demand_count` for determining whether a skill is high demand or not, we are not removing these rows.

# %%
# Histogram Plotting
fig, ax = plt.subplots(2,2,figsize=(12,5))

# Reset index so that histogram plots can be generated without errors
df = df.reset_index()

# median_days_open histogram
sns.histplot(data=df, x='median_days_open', ax=ax[0][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 5
#       1 # Histogram Plotting
#       2 fig, ax = plt.subplots(2,2,figsize=(12,5))
#       3
#       4 # median_days_open histogram
# ----> 5 sns.histplot(data=df, x='median_days_open', ax=ax[0][0])
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)   1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)   1446         **kwargs,
#    1447     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\distributions.py:427, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     424 histograms = {}
#     426 # Do pre-compute housekeeping related to multiple groups
# --> 427 all_data = self.comp_data.dropna()
#     428 all_weights = all_data.get("weights", None)
#     430 multiple_histograms = set(self.variables) - {"x", "y"}
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_base.py:1007, in VectorPlotter.comp_data(self)
#    1005         else:
#    1006             comp_col = pd.Series(dtype=float, name=var)
# -> 1007         comp_data.insert(0, var, comp_col)
#    1009     self._comp_data = comp_data
#    1011 return self._comp_data
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5646, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    5642             )
#    5643         elif isinstance(value, DataFrame):
#    5644             value = value.iloc[:, 0]
#    5645
# -> 5646         value, refs = self._sanitize_column(value)
#    5647         self._mgr.insert(loc, column, value, refs=refs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5751, in DataFrame._sanitize_column(self, value)
#    5747         assert not isinstance(value, DataFrame)
#    5748         if is_dict_like(value):
#    5749             if not isinstance(value, Series):
#    5750                 value = Series(value)
# -> 5751             return _reindex_for_setitem(value, self.index)
#    5752
#    5753         if is_list_like(value):
#    5754             com.require_length_match(value, self.index)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:16717, in _reindex_for_setitem(value, index)
#   16713     except ValueError as err:
#   16714         # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   16715         if not value.index.is_unique:
#   16716             # duplicate axis
# > 16717             raise err
#   16718
#   16719         raise TypeError(
#   16720             "incompatible index of inserted column with frame index"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:16717, in _reindex_for_setitem(value, index)
#   16713     except ValueError as err:
#   16714         # raised in MultiIndex.from_tuples, see test_insert_error_msmgs
#   16715         if not value.index.is_unique:
#   16716             # duplicate axis
# > 16717             raise err
#   16718
#   16719         raise TypeError(
#   16720             "incompatible index of inserted column with frame index"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:5525, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    5299 def reindex(  # type: ignore[override]
#    5300     self,
#    5301     index=None,
#    (...)   5309     tolerance=None,
#    5310 ) -> Series:
#    5311     """
#    5312     Conform Series to new index with optional filling logic.
#    5313
#    (...)   5523     See the :ref:`user guide <basics.reindexing>` for more.
#    5524     """
# -> 5525     return super().reindex(
#    5526         index=index,
#    5527         method=method,
#    5528         level=level,
#    5529         fill_value=fill_value,
#    5530         limit=limit,
#    5531         tolerance=tolerance,
#    5532         copy=copy,
#    5533     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:5476, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5472         if self._needs_reindex_multi(axes, method, level):
#    5473             return self._reindex_multi(axes, fill_value)
#    5474
#    5475         # perform the reindex on the axes
# -> 5476         return self._reindex_axes(
#    5477             axes, level, limit, tolerance, method, fill_value
#    5478         ).__finalize__(self, method="reindex")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:5498, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value)
#    5494             if labels is None:
#    5495                 continue
#    5496
#    5497             ax = self._get_axis(a)
# -> 5498             new_index, indexer = ax.reindex(
#    5499                 labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5500             )
#    5501
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:4253, in Index.reindex(self, target, method, level, limit, tolerance)
#    4250     raise ValueError("cannot handle a non-unique multi-index!")
#    4251 elif not self.is_unique:
#    4252     # GH#42568
# -> 4253     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4254 else:
#    4255     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels
