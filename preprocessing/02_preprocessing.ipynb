# %% [markdown]
# # Preprocessing Phase
# - This phase will cover the cleaning of dataset for use in modelling.
# - Since I decided not to drop rows with null values because they have other important metric present like `demand_count` etc, I will split the dataset into two samples, one cleaned (for modelling) and one with it's original structure for visualizations.
